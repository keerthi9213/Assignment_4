# %%
1. What exactly is []?
A.[] is a list data type

2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
A. spam[2]='hello'
   After assigning,the value in spam will be replaced by 'hello' string and when we print the list
   [2, 4, 'hello', 8, 10, 'a', 'b', 'c', 'd'] 

3. What is the value of spam[int(int('3' * 2) / 11)]?
A. spam=[2, 4, 'hello', 8, 10, 'a', 'b', 'c', 'd'] 
   int('3'*2)=33
   int(int('3'*2)/11)=3
   spam[int(int('3'*2)/11)]
   spam[3] which equals to 8

4. What is the value of spam[-1]?
A. spam=[2, 4, 'hello', 8, 10, 'a', 'b', 'c', 'd'] 
   spam[-1]=d

5. What is the value of spam[:2]?
A. spam=[2, 4, 'hello', 8, 10, 'a', 'b', 'c', 'd']
   spam[:2]=[2,4]

6. Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
   What is the value of bacon.index('cat')?
A. bacon=[3.14, 'cat,' 11, 'cat,' True] 
   bacon.index('cat') returns 1 (which is lower index)
    
7. How does bacon.append(99) change the look of the list value in bacon?
A. bacon=[3.14, 'cat', 11, 'cat', True, 99]

8. How does bacon.remove('cat') change the look of the list in bacon?
A. bacon=[3.14, 11, 'cat', True, 99]

9. What are the list concatenation and list replication operators?
A. list concatenation operator is + and list replication operator is *.

10. What is difference between the list methods append() and insert()?
A. append() adds value only at the last while insert() can add values anywhere in the list

11. What are the two methods for removing items from a list?
A. remove() and del statement

12. Describe how list values and string values are identical.
A. Both are collection of characters

13. What's the difference between tuples and lists?
A. Tuples are immutable while lists are mutable.

14. How do you type a tuple value that only contains the integer 42?
A. Tuple=(42)

15. How do you get a list value's tuple form? How do you get a tuple value's list form?
A. Tuple=(42,23,1)
print(list(Tuple))---->[42, 23, 1]
   List=[42,23,1]
print(tuple(List))---->(42, 23, 1)  

16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
A. They can be tuples and sets too

17. How do you distinguish between copy.copy() and copy.deepcopy()?
A. A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.
A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.
